# %%
from groq import Groq

# Connect to Groq API using my key
client = Groq(api_key="YOUR_API_KEY")

# 5 example sentences
samples = [
    "Apple CEO Steve Jobs announced a new iPhone 16 on 9/9/2024 in USA.",
    "Elon Musk's Tesla reported $25 billion in revenueon October 16th, 2026 in Austin, Texas.",
    "Egyptian footballer Mohamed Salah scored 2 goals against Manchester City on December 1st.",
    "NASA launched the Artemis II mission on March 15th, 2025 from Kennedy Space Center in Florida.",
    "Amazon founder Jeff Bezos was in Canada last Monday.",
]

# send text to the AI and pull out the facts
def extract(text):
    response = client.chat.completions.create(  # dee el function that sends the chat to the ai
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": """You are an information extraction assistant.
Extract the following fields from the text:
- Person
- Organization
- Location
- Date
- Event
Reply in this EXACT format:
Person: ...
Organization: ...
Location: ...
Date: ...
Event: ...
If a field is not found, write N/A."""},  # instructions to the ai
            {"role": "user", "content": f"Text: {text}"}  # the sentence we send
        ]
    )
    return response.choices[0].message.content.strip()  # first response only

print("=" * 60)
print("INFORMATION EXTRACTION — 5 SAMPLE TESTS")
print("=" * 60)
print("")

for i in range(len(samples)):  # loop over every text
    text = samples[i]
    result = extract(text)  # send to AI and get facts back
    print(f"Sample {i+1}: {text}")
    print("-" * 40)
    print(result)
    print()

print("=" * 60)
# Out:
# ============================================================
# INFORMATION EXTRACTION — 5 SAMPLE TESTS
# ============================================================
#
# Sample 1: Apple CEO Steve Jobs announced a new iPhone 16 on 9/9/2024 in USA.
# ----------------------------------------
# Person: Steve Jobs
# Organization: Apple
# Location: USA
# Date: 9/9/2024
# Event: announcement of a new iPhone 16
#
# Sample 2: Elon Musk's Tesla reported $25 billion in revenueon October 16th, 2026 in Austin, Texas.
# ----------------------------------------
# Person: Elon Musk
# Organization: Tesla
# Location: Austin, Texas
# Date: October 16th, 2026
# Event: Reporting $25 billion in revenue
#
# Sample 3: Egyptian footballer Mohamed Salah scored 2 goals against Manchester City on December 1st.
# ----------------------------------------
# Person: Mohamed Salah
# Organization: Manchester City
# Location: N/A
# Date: December 1st
# Event: football match
#
# Sample 4: NASA launched the Artemis II mission on March 15th, 2025 from Kennedy Space Center in Florida.
# ----------------------------------------
# Person: N/A
# Organization: NASA
# Location: Kennedy Space Center, Florida
# Date: March 15th, 2025
# Event: Artemis II mission launch
#
# Sample 5: Amazon founder Jeff Bezos was in Canada last Monday.
# ----------------------------------------
# Person: Jeff Bezos
# Organization: Amazon
# Location: Canada
# Date: Last Monday
# Event: N/A
#
# ============================================================
